# %%
# def greet():
#     print("heemant")
    
#     greet()

# greet()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 658

# %%
count = 0

def greet():
    global count
    if count == 4:
        return

    count += 1
    print("heemant")
    greet()

greet()
# Out:
# heemant
# heemant
# heemant
# heemant

# %%
count = 0

def greet():
    global count
    if count == 4:
        return

    count += 1
    greet()
    print("heemant")

greet()
# Out:
# heemant
# heemant
# heemant
# heemant
