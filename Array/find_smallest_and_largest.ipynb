# %%
num = [5,15,22,1,-15,-24]
size = 6

smallest = num[0]
largest = num[1]

for i in range(size):
    
    if num[i]<=smallest:
        smallest = num[i]
        
    if num[i]>= largest:
        largest = num[i]
        
print("smallest", smallest)
print("largest", largest)
# Out:
# smallest -24
# largest 22
